# %% [markdown]
# <a href="https://colab.research.google.com/github/techwithanirudh/Shared/blob/master/mainMobSuper2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()

# %%
from google.colab import files
import requests
import base64
import os
import cv2
from google.colab.patches import cv2_imshow

uploaded = files.upload()

for fname in uploaded.keys():
  fname = fname

with open('/content/' + fname, 'rb') as img_file:
    my_string = base64.b64encode(img_file.read())

id = 'f469a8aea565'  #@param {type: "string"}
url = f'https://{id}.ngrok.io/path/{fname}/compute'
imgdata = bytes(requests.post(url, my_string).text, 'utf-8')
print(type(imgdata))
imgdata = base64.b64decode(imgdata)
with open(f'/content/toon{fname}', 'wb') as f:
  f.write(imgdata)
cv2_imshow(cv2.imread(f'/content/toon{fname}'))
# Out:
#      <input type="file" id="files-7eff6c51-e321-4efa-9635-4af2790eae85" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7eff6c51-e321-4efa-9635-4af2790eae85">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving face.png to face.png
# <class 'bytes'>
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7FB4258BD0F0>
